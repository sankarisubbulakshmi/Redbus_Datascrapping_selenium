# %%
import pandas as pd

# %%
import datetime as dt

# %% [markdown]
# Andhra df EDA

# %%
Apsrtc_bus_details = pd.read_csv(r"C:\Users\shank\Desktop\redbus\apsrtc_bus_details.csv")
Apsrtc_bus_details
# Out:
#              Bus_name                                        Bus_type  \
# 0      APSRTC - 35271                              INDRA(A.C. Seater)
# 1       APSRTC - 3585      AMARAVATHI (VOLVO / SCANIA A.C Multi Axle)
# 2      APSRTC - 35133      AMARAVATHI (VOLVO / SCANIA A.C Multi Axle)
# 3      APSRTC - 35135      AMARAVATHI (VOLVO / SCANIA A.C Multi Axle)
# 4      APSRTC - 35085  DOLPHIN CRUISE (VOLVO / SCANIA A.C Multi Axle)
# ...               ...                                             ...
# 3998  Sudheer Travels                           NON A/C Sleeper (2+1)
# 3999      SRS Travels         Volvo Multi-Axle A/C Semi Sleeper (2+2)
# 4000   SLC Road Lines                               A/C Sleeper (2+1)
# 4001     KSM Roadways                   Bharat Benz A/C Sleeper (2+1)
# 4002     Bmcc Travels                           NON A/C Sleeper (2+1)
#
#      Departure_time Arrival_time   Ratings Duration     Price  \
# 0             16:00        21:50   3.1\n78  05h 50m   INR 567
# ...

# %%
Apsrtc_bus_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4003 entries, 0 to 4002
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Bus_name         4003 non-null   object
#  1   Bus_type         4003 non-null   object
#  2   Departure_time   4003 non-null   object
#  3   Arrival_time     4003 non-null   object
#  4   Ratings          4003 non-null   object
#  5   Duration         4003 non-null   object
#  6   Price            4003 non-null   object
#  7   Seats_available  4003 non-null   object
#  8   Route_name       4003 non-null   object
#  9   Route_link       4003 non-null   object
# dtypes: object(10)
# memory usage: 312.9+ KB

# %%
# Remove INR from Price and convert to integer using lambda
Apsrtc_bus_details['Price'] = Apsrtc_bus_details['Price'].apply(lambda x: int(float(x.replace('INR ', '').replace(',', ''))))

#Rating conversion
Apsrtc_bus_details['Ratings'] = Apsrtc_bus_details['Ratings'].replace('New', '0')
Apsrtc_bus_details['Ratings'] = Apsrtc_bus_details['Ratings'].replace(' ', '0')

Apsrtc_bus_details['Ratings'] = Apsrtc_bus_details['Ratings'].str.split('\n').str[0].astype(float)

# Extract numeric values from Seats_available using lambda
Apsrtc_bus_details['Seats_available'] = Apsrtc_bus_details['Seats_available'].apply(lambda x: int(''.join(filter(str.isdigit, x))))

# %%
Apsrtc_bus_details
# Out:
#              Bus_name                                        Bus_type  \
# 0      APSRTC - 35271                              INDRA(A.C. Seater)
# 1       APSRTC - 3585      AMARAVATHI (VOLVO / SCANIA A.C Multi Axle)
# 2      APSRTC - 35133      AMARAVATHI (VOLVO / SCANIA A.C Multi Axle)
# 3      APSRTC - 35135      AMARAVATHI (VOLVO / SCANIA A.C Multi Axle)
# 4      APSRTC - 35085  DOLPHIN CRUISE (VOLVO / SCANIA A.C Multi Axle)
# ...               ...                                             ...
# 3998  Sudheer Travels                           NON A/C Sleeper (2+1)
# 3999      SRS Travels         Volvo Multi-Axle A/C Semi Sleeper (2+2)
# 4000   SLC Road Lines                               A/C Sleeper (2+1)
# 4001     KSM Roadways                   Bharat Benz A/C Sleeper (2+1)
# 4002     Bmcc Travels                           NON A/C Sleeper (2+1)
#
#      Departure_time Arrival_time  Ratings Duration  Price  Seats_available  \
# ...

# %%
print(Apsrtc_bus_details.dtypes)
# Out:
# Bus_name            object
# Bus_type            object
# Departure_time      object
# Arrival_time        object
# Ratings            float64
# Duration            object
# Price                int64
# Seats_available      int64
# Route_name          object
# Route_link          object
# dtype: object

# %% [markdown]
# Kerala EDA

# %%
keralartc_bus_details =pd.read_csv(r"C:\Users\shank\Desktop\redbus\keralartc_bus_details.csv")
keralartc_bus_details
# Out:
#                   Bus_name                                Bus_type  \
# 0    KSRTC (Kerala) - 1210  SWIFT-HYBRID NON AC SEATER CUM SLEEPER
# 1     KSRTC (Kerala) - 129             SWIFT-GARUDA A/C SEATER BUS
# 2     KSRTC (Kerala) - 235       Swift Deluxe Non AC Air Bus (2+2)
# 3     KSRTC (Kerala) - 370                           AC MULTI AXLE
# 4      KSRTC (Kerala) - 97       Swift Deluxe Non AC Air Bus (2+2)
# ..                     ...                                     ...
# 701         Cochin Express            Bharat Benz A/C Seater (2+2)
# 702          Sonia Travels                  A/C Semi Sleeper (2+2)
# 703          Sonia Travels                A/C Seater/Sleeper (2+1)
# 704          Sonia Travels                A/C Seater/Sleeper (2+1)
# 705          Sonia Travels                  A/C Semi Sleeper (2+2)
#
#     Departure_time Arrival_time  Ratings Duration     Price  \
# 0            12:55        21:15  3.8\n20  08h 20m   INR 740
# ...

# %%
keralartc_bus_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 706 entries, 0 to 705
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Bus_name         706 non-null    object
#  1   Bus_type         706 non-null    object
#  2   Departure_time   706 non-null    object
#  3   Arrival_time     706 non-null    object
#  4   Ratings          706 non-null    object
#  5   Duration         706 non-null    object
#  6   Price            706 non-null    object
#  7   Seats_available  706 non-null    object
#  8   Route_name       706 non-null    object
#  9   Route_link       706 non-null    object
# dtypes: object(10)
# memory usage: 55.3+ KB

# %%
# Remove INR from Price and convert to integer using lambda
keralartc_bus_details['Price'] = keralartc_bus_details['Price'].apply(lambda x: int(float(x.replace('INR ', '').replace(',', ''))))

#Rating conversion
keralartc_bus_details['Ratings'] = keralartc_bus_details['Ratings'].replace('New', '0')
keralartc_bus_details['Ratings'] = keralartc_bus_details['Ratings'].replace(' ', '0')

keralartc_bus_details['Ratings'] = keralartc_bus_details['Ratings'].str.split('\n').str[0].astype(float)

# Extract numeric values from Seats_available using lambda
keralartc_bus_details['Seats_available'] = keralartc_bus_details['Seats_available'].apply(lambda x: int(''.join(filter(str.isdigit, x))))

# %%
#time convertion
keralartc_bus_details['Departure_time'] = keralartc_bus_details['Departure_time'].astype(str).str.strip()
keralartc_bus_details['Arrival_time'] = keralartc_bus_details['Arrival_time'].astype(str).str.strip()

# Convert to datetime objects first
keralartc_bus_details['Departure_time'] = pd.to_datetime(keralartc_bus_details['Departure_time'], format='%H:%M', errors='coerce').dt.time
keralartc_bus_details['Arrival_time'] = pd.to_datetime(keralartc_bus_details['Arrival_time'], format='%H:%M', errors='coerce').dt.time

# %%
keralartc_bus_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 706 entries, 0 to 705
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Bus_name         706 non-null    object
#  1   Bus_type         706 non-null    object
#  2   Departure_time   706 non-null    object
#  3   Arrival_time     706 non-null    object
#  4   Ratings          706 non-null    float64
#  5   Duration         706 non-null    object
#  6   Price            706 non-null    int64
#  7   Seats_available  706 non-null    int64
#  8   Route_name       706 non-null    object
#  9   Route_link       706 non-null    object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 55.3+ KB

# %% [markdown]
# Telengana EDA

# %%
tsrtc_bus_details =pd.read_csv(r"C:\Users\shank\Desktop\redbus\tsrtc_bus_details.csv")
tsrtc_bus_details
# Out:
#                         Bus_name                                Bus_type  \
# 0                   TSRTC - 8918  SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)
# 1                   TSRTC - 8681   RAJADHANI AC (CONVERTED METRO LUXURY)
# 2                   TSRTC - 8617  SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)
# 3                   TSRTC - 8736  SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)
# 4                   TSRTC - 8977  SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)
# ...                          ...                                     ...
# 1928                Mozo travels                       A/C Sleeper (2+1)
# 1929         SREE LEKYAA TRAVELS                   NON A/C Sleeper (2+1)
# 1930                  RK Travels          Non A/C Seater / Sleeper (2+1)
# 1931  GOWTHAMI TOURS AND TRAVELS                       A/C Sleeper (2+1)
# 1932  GOWTHAMI TOURS AND TRAVELS                       A/C Sleeper (2+1)
#
#      Departure_time Arrival_time  Ratings     Duration     Price  \
# ...

# %%
tsrtc_bus_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1933 entries, 0 to 1932
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Bus_name         1933 non-null   object
#  1   Bus_type         1933 non-null   object
#  2   Departure_time   1933 non-null   object
#  3   Arrival_time     1933 non-null   object
#  4   Ratings          1933 non-null   object
#  5   Duration         1933 non-null   object
#  6   Price            1933 non-null   object
#  7   Seats_available  1933 non-null   object
#  8   Route_name       1933 non-null   object
#  9   Route_link       1933 non-null   object
# dtypes: object(10)
# memory usage: 151.1+ KB

# %%
# Remove INR from Price and convert to integer using lambda
tsrtc_bus_details['Price'] = tsrtc_bus_details['Price'].apply(lambda x: int(float(x.replace('INR ', '').replace(',', ''))))

#Rating conversion
tsrtc_bus_details['Ratings'] = tsrtc_bus_details['Ratings'].replace('New', '0')
tsrtc_bus_details['Ratings'] = tsrtc_bus_details['Ratings'].replace(' ', '0')

tsrtc_bus_details['Ratings'] = tsrtc_bus_details['Ratings'].str.split('\n').str[0].astype(float)

# Extract numeric values from Seats_available using lambda
tsrtc_bus_details['Seats_available'] = tsrtc_bus_details['Seats_available'].apply(lambda x: int(''.join(filter(str.isdigit, x))))

# %%
tsrtc_bus_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1933 entries, 0 to 1932
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Bus_name         1933 non-null   object
#  1   Bus_type         1933 non-null   object
#  2   Departure_time   1933 non-null   object
#  3   Arrival_time     1933 non-null   object
#  4   Ratings          1933 non-null   float64
#  5   Duration         1933 non-null   object
#  6   Price            1933 non-null   int64
#  7   Seats_available  1933 non-null   int64
#  8   Route_name       1933 non-null   object
#  9   Route_link       1933 non-null   object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 151.1+ KB

# %% [markdown]
# HRTC EDA

# %%
hrtc_bus_details =pd.read_csv(r"C:\Users\shank\Desktop\redbus\hrtc_bus_details.csv")
hrtc_bus_details
# Out:
#                     Bus_name                                 Bus_type  \
# 0                 HRTC - 551                      A/C Executive (2+3)
# 1                 HRTC - 525               Ordinary 3+2 Non AC Seater
# 2                 HRTC - 538               Ordinary 3+2 Non AC Seater
# 3                  HRTC - 93       Himsuta AC Seater Volvo/Scania 2+2
# 4                 HRTC - 301               Ordinary 3+2 Non AC Seater
# ...                      ...                                      ...
# 1088        Bharmani Travels             Volvo A/C Semi Sleeper (2+2)
# 1089        Northern Travels             Volvo A/C Semi Sleeper (2+2)
# 1090  Triptara tour & Travel  Scania Multi-Axle AC Semi Sleeper (2+2)
# 1091                 FlixBus                         A/C Seater (2+2)
# 1092       City Land Travels             Volvo A/C Semi Sleeper (2+2)
#
#      Departure_time Arrival_time  Ratings Duration    Price  \
# 0             15:30        01:30  3.5\n10  10h 00m  INR 622
# ...

# %%
hrtc_bus_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1093 entries, 0 to 1092
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Bus_name         1057 non-null   object
#  1   Bus_type         1057 non-null   object
#  2   Departure_time   1057 non-null   object
#  3   Arrival_time     1057 non-null   object
#  4   Ratings          1057 non-null   object
#  5   Duration         1057 non-null   object
#  6   Price            1057 non-null   object
#  7   Seats_available  1057 non-null   object
#  8   Route_name       1093 non-null   object
#  9   Route_link       1093 non-null   object
# dtypes: object(10)
# memory usage: 85.5+ KB

# %%
hrtc_bus_details.dropna(inplace = True)
hrtc_bus_details.reset_index(drop=True, inplace=True)
hrtc_bus_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1057 entries, 0 to 1056
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Bus_name         1057 non-null   object
#  1   Bus_type         1057 non-null   object
#  2   Departure_time   1057 non-null   object
#  3   Arrival_time     1057 non-null   object
#  4   Ratings          1057 non-null   object
#  5   Duration         1057 non-null   object
#  6   Price            1057 non-null   object
#  7   Seats_available  1057 non-null   object
#  8   Route_name       1057 non-null   object
#  9   Route_link       1057 non-null   object
# dtypes: object(10)
# memory usage: 82.7+ KB

# %%
# Remove INR from Price and convert to integer using lambda
hrtc_bus_details['Price'] = hrtc_bus_details['Price'].apply(lambda x: int(float(x.replace('INR ', '').replace(',', ''))))

#Rating conversion
hrtc_bus_details['Ratings'] = hrtc_bus_details['Ratings'].replace('New', '0')
hrtc_bus_details['Ratings'] = hrtc_bus_details['Ratings'].replace(' ', '0')

hrtc_bus_details['Ratings'] = hrtc_bus_details['Ratings'].str.split('\n').str[0].astype(float)

# Extract numeric values from Seats_available using lambda
hrtc_bus_details['Seats_available'] = hrtc_bus_details['Seats_available'].apply(lambda x: int(''.join(filter(str.isdigit, x))))

# %%
hrtc_bus_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1057 entries, 0 to 1056
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Bus_name         1057 non-null   object
#  1   Bus_type         1057 non-null   object
#  2   Departure_time   1057 non-null   object
#  3   Arrival_time     1057 non-null   object
#  4   Ratings          1057 non-null   float64
#  5   Duration         1057 non-null   object
#  6   Price            1057 non-null   int64
#  7   Seats_available  1057 non-null   int64
#  8   Route_name       1057 non-null   object
#  9   Route_link       1057 non-null   object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 82.7+ KB

# %% [markdown]
# RSRTC EDA

# %%
rsrtc_bus_details =pd.read_csv(r"C:\Users\shank\Desktop\redbus\rsrtc_bus_details.csv")
rsrtc_bus_details
# Out:
#                  Bus_name                                   Bus_type  \
# 0          RSRTC - 146140  Super Luxury Volvo AC Seater Pushback 2+2
# 1          RSRTC - 169078                NON AC Seater / Sleeper 2+1
# 2          RSRTC - 178737                  Express Non AC Seater 2+3
# 3          RSRTC - 190572                  Express Non AC Seater 2+3
# 4          RSRTC - 175650  Super Luxury Volvo AC Seater Pushback 2+2
# ..                    ...                                        ...
# 898         Royal Travels                 A/C Seater / Sleeper (2+1)
# 899  Amar Travels(Jaipur)                           AC Sleeper (2+1)
# 900        Sharma travels                 A/C Seater / Sleeper (2+1)
# 901  Amar Travels(Jaipur)                 A/C Seater / Sleeper (2+1)
# 902           M R Travels  Volvo Multi-Axle A/C seater/sleeper (2+1)
#
#     Departure_time Arrival_time  Ratings Duration     Price  \
# 0            14:46        18:48  4.2\n61  04h 02m   INR 460
# ...

# %%
rsrtc_bus_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 903 entries, 0 to 902
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Bus_name         903 non-null    object
#  1   Bus_type         903 non-null    object
#  2   Departure_time   903 non-null    object
#  3   Arrival_time     903 non-null    object
#  4   Ratings          903 non-null    object
#  5   Duration         903 non-null    object
#  6   Price            903 non-null    object
#  7   Seats_available  903 non-null    object
#  8   Route_name       903 non-null    object
#  9   Route_link       903 non-null    object
# dtypes: object(10)
# memory usage: 70.7+ KB

# %%
# Remove INR from Price and convert to integer using lambda
rsrtc_bus_details['Price'] = rsrtc_bus_details['Price'].apply(lambda x: int(float(x.replace('INR ', '').replace(',', ''))))

#Rating conversion
rsrtc_bus_details['Ratings'] = rsrtc_bus_details['Ratings'].replace('New', '0')
rsrtc_bus_details['Ratings'] = rsrtc_bus_details['Ratings'].replace(' ', '0')

rsrtc_bus_details['Ratings'] = rsrtc_bus_details['Ratings'].str.split('\n').str[0].astype(float)

# Extract numeric values from Seats_available using lambda
rsrtc_bus_details['Seats_available'] = rsrtc_bus_details['Seats_available'].apply(lambda x: int(''.join(filter(str.isdigit, x))))

# %%
rsrtc_bus_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 903 entries, 0 to 902
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Bus_name         903 non-null    object
#  1   Bus_type         903 non-null    object
#  2   Departure_time   903 non-null    object
#  3   Arrival_time     903 non-null    object
#  4   Ratings          903 non-null    float64
#  5   Duration         903 non-null    object
#  6   Price            903 non-null    int64
#  7   Seats_available  903 non-null    int64
#  8   Route_name       903 non-null    object
#  9   Route_link       903 non-null    object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 70.7+ KB

# %% [markdown]
# SBSTC EDA

# %%
sbstc_bus_details =pd.read_csv(r"C:\Users\shank\Desktop\redbus\sbstc_bus_details.csv")
sbstc_bus_details
# Out:
#                                               Bus_name               Bus_type  \
# 0    SBSTC-BURDWAN - KARUNAMOYEE - 14:10 (BWN DEPOT...    Non AC Seater (2+3)
# 1     SBSTC-BURDWAN - KOLKATA - 14:30 (BWN DEPOT) - 30    Non AC Seater (2+3)
# 2    SBSTC-BURDWAN - KOLKATA - A/C - 15:00 (BWN DEP...        AC Seater (2+2)
# 3    SBSTC-BURDWAN - KARUNAMOYEE - 15:10 (BWN DEPOT...    Non AC Seater (2+3)
# 4     SBSTC-BURDWAN - KOLKATA - 15:25 (BWN DEPOT) - 33    Non AC Seater (2+3)
# ..                                                 ...                    ...
# 501  SBSTC-KOLKATA - SURI - 14:30 - (Suri Depot) - 652    Non AC Seater (2+3)
# 502  SBSTC-KOLKATA - SURI - 15:30 - (Suri Depot) - 655    Non AC Seater (2+3)
# 503  SBSTC-KOLKATA - SURI - 16: 30 - (Suri Depot) -...    Non AC Seater (2+3)
# 504  SBSTC-KOLKATA - SURI - 18:00 - (Suri Depot) - ...    Non AC Seater (2+3)
# 505  WBTC (CTC) KOLKATA -BOLPUR - SURI (AC-VOLVO) -...  Volvo AC Seater (2+2)
#
# ...

# %%
sbstc_bus_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Bus_name         506 non-null    object
#  1   Bus_type         506 non-null    object
#  2   Departure_time   506 non-null    object
#  3   Arrival_time     506 non-null    object
#  4   Ratings          506 non-null    object
#  5   Duration         506 non-null    object
#  6   Price            506 non-null    object
#  7   Seats_available  506 non-null    object
#  8   Route_name       506 non-null    object
#  9   Route_link       506 non-null    object
# dtypes: object(10)
# memory usage: 39.7+ KB

# %%
# Remove INR from Price and convert to integer using lambda
sbstc_bus_details['Price'] = sbstc_bus_details['Price'].apply(lambda x: int(float(x.replace('INR ', '').replace(',', ''))))

#Rating conversion
sbstc_bus_details['Ratings'] = sbstc_bus_details['Ratings'].replace('New', '0')
sbstc_bus_details['Ratings'] = sbstc_bus_details['Ratings'].replace(' ', '0')

sbstc_bus_details['Ratings'] = sbstc_bus_details['Ratings'].str.split('\n').str[0].astype(float)

# Extract numeric values from Seats_available using lambda
sbstc_bus_details['Seats_available'] = sbstc_bus_details['Seats_available'].apply(lambda x: int(''.join(filter(str.isdigit, x))))

# %%
sbstc_bus_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Bus_name         506 non-null    object
#  1   Bus_type         506 non-null    object
#  2   Departure_time   506 non-null    object
#  3   Arrival_time     506 non-null    object
#  4   Ratings          506 non-null    float64
#  5   Duration         506 non-null    object
#  6   Price            506 non-null    int64
#  7   Seats_available  506 non-null    int64
#  8   Route_name       506 non-null    object
#  9   Route_link       506 non-null    object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 39.7+ KB

# %% [markdown]
# UPSRTC EDA

# %%
upsrtc_bus_details =pd.read_csv(r"C:\Users\shank\Desktop\redbus\upsrtc_bus_details.csv")
upsrtc_bus_details
# Out:
#                             Bus_name                        Bus_type  \
# 0                   UPSRTC - RKD0089      Ordinary Non AC Seater 2+3
# 1                   UPSRTC - RKD0119          Shatabdi AC Seater 2+2
# 2                   UPSRTC - RKD0130           Janrath AC Seater 2+3
# 3                   UPSRTC - BLY0111           Janrath AC Seater 2+2
# 4                   UPSRTC - HDD0063      Ordinary Non AC Seater 2+3
# ..                               ...                             ...
# 971        MISHRA BANDHU BUS SERVICE      A/C Seater / Sleeper (2+1)
# 972   Samay Shatabdi Travels Pvt Ltd           NON A/C Sleeper (2+1)
# 973                     Maan Travels     NON AC Seater / Sleeper 2+1
# 974          Maa Laxmi Bihar Express  Non A/C Seater / Sleeper (2+1)
# 975  Shree Balajee Travels And Cargo      A/C Seater / Sleeper (2+1)
#
#     Departure_time Arrival_time  Ratings Duration     Price  \
# 0            16:01        23:59      3.3  07h 58m   INR 476
# ...

# %%
upsrtc_bus_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 976 entries, 0 to 975
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Bus_name         976 non-null    object
#  1   Bus_type         976 non-null    object
#  2   Departure_time   976 non-null    object
#  3   Arrival_time     976 non-null    object
#  4   Ratings          976 non-null    object
#  5   Duration         976 non-null    object
#  6   Price            976 non-null    object
#  7   Seats_available  976 non-null    object
#  8   Route_name       976 non-null    object
#  9   Route_link       976 non-null    object
# dtypes: object(10)
# memory usage: 76.4+ KB

# %%
# Remove INR from Price and convert to integer using lambda
upsrtc_bus_details['Price'] = upsrtc_bus_details['Price'].apply(lambda x: int(float(x.replace('INR ', '').replace(',', ''))))

#Rating conversion
upsrtc_bus_details['Ratings'] = upsrtc_bus_details['Ratings'].replace('New', '0')
upsrtc_bus_details['Ratings'] = upsrtc_bus_details['Ratings'].replace(' ', '0')

upsrtc_bus_details['Ratings'] = upsrtc_bus_details['Ratings'].str.split('\n').str[0].astype(float)

# Extract numeric values from Seats_available using lambda
upsrtc_bus_details['Seats_available'] = upsrtc_bus_details['Seats_available'].apply(lambda x: int(''.join(filter(str.isdigit, x))))

# %%
upsrtc_bus_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 976 entries, 0 to 975
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Bus_name         976 non-null    object
#  1   Bus_type         976 non-null    object
#  2   Departure_time   976 non-null    object
#  3   Arrival_time     976 non-null    object
#  4   Ratings          976 non-null    float64
#  5   Duration         976 non-null    object
#  6   Price            976 non-null    int64
#  7   Seats_available  976 non-null    int64
#  8   Route_name       976 non-null    object
#  9   Route_link       976 non-null    object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 76.4+ KB

# %% [markdown]
# WBTC EDA

# %%
wbtc_bus_details=pd.read_csv(r"C:\Users\shank\Desktop\redbus\wbtc_bus_details.csv")
wbtc_bus_details
# Out:
#                                               Bus_name  \
# 0    SBSTC-DURGAPUR - KARUNAMOYEE - A/C - 15:10 (DG...
# 1    SBSTC-BANKURA - KARUNAMOYEE - 14:15 (BNK DEPOT...
# 2    SBSTC-ASANSOL - KOLKATA - 15:05 (HWH DEPOT) - 210
# 3    SBSTC-ASANSOL - KARUNAMOYEE - 15:10 (BEL DEPOT...
# 4                                                  NaN
# ..                                                 ...
# 203                         Shyamoli Paribahan Pvt Ltd
# 204                                      Royal Cruiser
# 205                                     Beauty Travels
# 206                             Pariwartan Bus Service
# 207                                   Maharani Travels
#
#                            Bus_type Departure_time Arrival_time   Ratings  \
# 0                   AC Seater (2+2)          15:10        19:10  3.0\n163
# 1               Non AC Seater (2+3)          16:00        20:00   3.7\n62
# 2               Non AC Seater (2+3)          16:15        19:45   2.9\n40
# ...

# %%
wbtc_bus_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Bus_name         202 non-null    object
#  1   Bus_type         201 non-null    object
#  2   Departure_time   202 non-null    object
#  3   Arrival_time     202 non-null    object
#  4   Ratings          202 non-null    object
#  5   Duration         202 non-null    object
#  6   Price            202 non-null    object
#  7   Seats_available  202 non-null    object
#  8   Route_name       208 non-null    object
#  9   Route_link       208 non-null    object
# dtypes: object(10)
# memory usage: 16.4+ KB

# %%
wbtc_bus_details.dropna(inplace = True)
wbtc_bus_details.reset_index(drop=True, inplace=True)
wbtc_bus_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Bus_name         201 non-null    object
#  1   Bus_type         201 non-null    object
#  2   Departure_time   201 non-null    object
#  3   Arrival_time     201 non-null    object
#  4   Ratings          201 non-null    object
#  5   Duration         201 non-null    object
#  6   Price            201 non-null    object
#  7   Seats_available  201 non-null    object
#  8   Route_name       201 non-null    object
#  9   Route_link       201 non-null    object
# dtypes: object(10)
# memory usage: 15.8+ KB

# %%
# Remove INR from Price and convert to integer using lambda
wbtc_bus_details['Price'] = wbtc_bus_details['Price'].apply(lambda x: int(float(x.replace('INR ', '').replace(',', ''))))

#Rating conversion
wbtc_bus_details['Ratings'] = wbtc_bus_details['Ratings'].replace('New', '0')
wbtc_bus_details['Ratings'] = wbtc_bus_details['Ratings'].replace(' ', '0')

wbtc_bus_details['Ratings'] = wbtc_bus_details['Ratings'].str.split('\n').str[0].astype(float)

# Extract numeric values from Seats_available using lambda
wbtc_bus_details['Seats_available'] = wbtc_bus_details['Seats_available'].apply(lambda x: int(''.join(filter(str.isdigit, x))))

# %%
wbtc_bus_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Bus_name         201 non-null    object
#  1   Bus_type         201 non-null    object
#  2   Departure_time   201 non-null    object
#  3   Arrival_time     201 non-null    object
#  4   Ratings          201 non-null    float64
#  5   Duration         201 non-null    object
#  6   Price            201 non-null    int64
#  7   Seats_available  201 non-null    int64
#  8   Route_name       201 non-null    object
#  9   Route_link       201 non-null    object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 15.8+ KB

# %% [markdown]
# CTU EDA

# %%
ctu_bus_details = pd.read_csv(r"C:\Users\shank\Desktop\redbus\ctu_bus_details.csv")
ctu_bus_details
# Out:
#                                               Bus_name  \
# 0      Chandigarh Transport Undertaking (CTU) - 165697
# 1      Chandigarh Transport Undertaking (CTU) - 165709
# 2      Chandigarh Transport Undertaking (CTU) - 165720
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 399                                                NaN
# 400                                                NaN
# 401                                        HRTC - 1514
# 402                                        HRTC - 1285
# 403  Asian's Shina Tour & Travels (Swoyambhu Manjus...
#
#                        Bus_type Departure_time Arrival_time  Ratings Duration  \
# 0             HVAC Seater (2+3)          14:00        19:35  4.1\n40  05h 35m
# 1             HVAC Seater (2+3)          14:30        20:05  3.9\n31  05h 35m
# ...

# %%
ctu_bus_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404 entries, 0 to 403
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Bus_name         200 non-null    object
#  1   Bus_type         195 non-null    object
#  2   Departure_time   200 non-null    object
#  3   Arrival_time     200 non-null    object
#  4   Ratings          200 non-null    object
#  5   Duration         200 non-null    object
#  6   Price            200 non-null    object
#  7   Seats_available  197 non-null    object
#  8   Route_name       404 non-null    object
#  9   Route_link       404 non-null    object
# dtypes: object(10)
# memory usage: 31.7+ KB

# %%
ctu_bus_details.dropna(inplace = True)
ctu_bus_details.reset_index(drop=True, inplace=True)
ctu_bus_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Bus_name         195 non-null    object
#  1   Bus_type         195 non-null    object
#  2   Departure_time   195 non-null    object
#  3   Arrival_time     195 non-null    object
#  4   Ratings          195 non-null    object
#  5   Duration         195 non-null    object
#  6   Price            195 non-null    object
#  7   Seats_available  195 non-null    object
#  8   Route_name       195 non-null    object
#  9   Route_link       195 non-null    object
# dtypes: object(10)
# memory usage: 15.4+ KB

# %%
# Remove INR from Price and convert to integer using lambda
ctu_bus_details['Price'] = ctu_bus_details['Price'].apply(lambda x: int(float(x.replace('INR ', '').replace(',', ''))))

#Rating conversion
ctu_bus_details['Ratings'] = ctu_bus_details['Ratings'].replace('New', '0')
ctu_bus_details['Ratings'] = ctu_bus_details['Ratings'].replace(' ', '0')

ctu_bus_details['Ratings'] = ctu_bus_details['Ratings'].str.split('\n').str[0].astype(float)

# Extract numeric values from Seats_available using lambda
ctu_bus_details['Seats_available'] = ctu_bus_details['Seats_available'].apply(lambda x: int(''.join(filter(str.isdigit, x))))

# %%
ctu_bus_details
# Out:
#                                               Bus_name  \
# 0      Chandigarh Transport Undertaking (CTU) - 165697
# 1      Chandigarh Transport Undertaking (CTU) - 165709
# 2      Chandigarh Transport Undertaking (CTU) - 165720
# 3                                           HRTC - 562
# 4                                           HRTC - 551
# ..                                                 ...
# 190                                        HRTC - 1104
# 191                                        HRTC - 1107
# 192                                        HRTC - 1514
# 193                                        HRTC - 1285
# 194  Asian's Shina Tour & Travels (Swoyambhu Manjus...
#
#                        Bus_type Departure_time Arrival_time  Ratings Duration  \
# 0             HVAC Seater (2+3)          14:00        19:35      4.1  05h 35m
# 1             HVAC Seater (2+3)          14:30        20:05      3.9  05h 35m
# ...

# %% [markdown]
# ASTC EDA

# %%
astc_bus_details= pd.read_csv(r"C:\Users\shank\Desktop\scraping\astc_bus_details.csv")
astc_bus_details
# Out:
#                                               Bus_name  \
# 0    Assam State Transport Corporation (ASTC) - 175396
# 1    Assam State Transport Corporation (ASTC) - 158332
# 2    Assam State Transport Corporation (ASTC) - 173420
# 3    Assam State Transport Corporation (ASTC) - 154930
# 4                                    NEELKANTH TRAVELS
# ..                                                 ...
# 171                                    NETWORK TRAVELS
# 172                                  Aniruddha Travels
# 173                                  Christina Travels
# 174                                          Maa Laxmi
# 175                               Purple Wings Coaches
#
#                            Bus_type Departure_time Arrival_time  Ratings  \
# 0               Volvo AC Seater 2+2          06:15        10:30      4.0
# 1      Bharat Benz A/C Seater (2+2)          07:10        11:00  4.9\n12
# 2      Bharat Benz A/C Seater (2+2)          10:35        15:15  4.1\n32
# ...

# %%
astc_bus_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 176 entries, 0 to 175
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Bus_name         176 non-null    object
#  1   Bus_type         176 non-null    object
#  2   Departure_time   176 non-null    object
#  3   Arrival_time     176 non-null    object
#  4   Ratings          176 non-null    object
#  5   Duration         176 non-null    object
#  6   Price            176 non-null    object
#  7   Seats_available  176 non-null    object
#  8   Route_name       176 non-null    object
#  9   Route_link       176 non-null    object
# dtypes: object(10)
# memory usage: 13.9+ KB

# %%
astc_bus_details['Price'] = astc_bus_details['Price'].apply(lambda x: int(float(x.replace('INR ', '').replace(',', ''))))
astc_bus_details['Ratings'] = astc_bus_details['Ratings'].apply(lambda x: x.split('\n')[0])
astc_bus_details['Seats_available'] = astc_bus_details['Seats_available'].apply(lambda x: int(''.join(filter(str.isdigit, x))))

# %%
astc_bus_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 176 entries, 0 to 175
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Bus_name         176 non-null    object
#  1   Bus_type         176 non-null    object
#  2   Departure_time   176 non-null    object
#  3   Arrival_time     176 non-null    object
#  4   Ratings          176 non-null    object
#  5   Duration         176 non-null    object
#  6   Price            176 non-null    int64
#  7   Seats_available  176 non-null    int64
#  8   Route_name       176 non-null    object
#  9   Route_link       176 non-null    object
# dtypes: int64(2), object(8)
# memory usage: 13.9+ KB

# %% [markdown]
# Pushing data to sql

# %%
# !pip install pymysql
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#pushing to sql database

from sqlalchemy import create_engine

# Create a MySQL database connection
engine = create_engine('mysql+pymysql://root:Shankii007@localhost/redbus')

# %%
Apsrtc_bus_details.to_sql('apsrtc_bus_details', con=engine, if_exists='replace', index=False)
keralartc_bus_details.to_sql('keralartc_bus_details', con=engine, if_exists='replace', index=False)
tsrtc_bus_details.to_sql('tsrtc_bus_details', con=engine, if_exists='replace', index=False)
hrtc_bus_details.to_sql('hrtc_bus_details', con=engine, if_exists='replace', index=False)
rsrtc_bus_details.to_sql('rsrtc_bus_details', con=engine, if_exists='replace', index=False)
sbstc_bus_details.to_sql('sbstc_bus_details', con=engine, if_exists='replace', index=False)
upsrtc_bus_details.to_sql('upsrtc_bus_details', con=engine, if_exists='replace', index=False)
wbtc_bus_details.to_sql('wbtc_bus_details', con=engine, if_exists='replace', index=False)
#astc_bus_details.to_sql('astc_bus_details', con=engine, if_exists='replace', index=False)

# %%
ctu_bus_details.to_sql('ctu_bus_details', con=engine, if_exists='replace', index=False)
# Out:
# 195
